# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.options.display.max_columns = 100

# %%
path = '../Data/2018_rc_data.xlsx'
xl = pd.ExcelFile(path)
sheet_names = xl.sheet_names
sheet_names
# Out:
# ['READ ME_Instructions',
#  'ACT',
#  'achievement',
#  'discipline',
#  'chronic_absenteeism',
#  'CTE',
#  'dropout',
#  'ELPA',
#  'enrollment',
#  'finance',
#  'grad_rate',
#  'growth',
#  'growth_subjects',
#  'indicator_level_grades',
#  'long_term_ell',
#  'overall_grades',
#  'postsec_enrollment',
#  'ready_grad',
#  'staffing',
#  'success_rate',
#  'teacher_retention',
#  'district_info',
#  'school_info']

# %%
for sheetname in sheet_names:
    if sheetname != 'READ ME_Instructions':
        vars()['df' + sheetname] = pd.read_excel(path, sheet_name= sheetname)

# %%
dfteacher_retention['percent_retained'] = dfteacher_retention['percent_retained'].replace('\*+', np.nan, regex=True)

# %%
dfteacher_retention['percent_retained'] = dfteacher_retention['percent_retained'].astype(float)

# %%
by_district_teach_ret=dfteacher_retention[dfteacher_retention['school_name'].isnull()&dfteacher_retention['district_name'].notnull()]

# %%
by_district_teach_ret=by_district_teach_ret[['district_name','percent_retained']]

# %%
school_overall_grades =  dfoverall_grades [['district_name','school_name', 'score_achievement', 'score_growth', 'score_absenteeism', 'score_grad']]

# %%
school_overall_grades.head()
# Out:
#              district_name                  school_name  score_achievement  \
# 0  Anderson County Schools  Anderson County High School                1.6
# 1  Anderson County Schools     Andersonville Elementary                2.2
# 2  Anderson County Schools        Briceville Elementary                3.0
# 3  Anderson County Schools           Claxton Elementary                3.2
# 4  Anderson County Schools        Clinton Middle School                2.0
#
#    score_growth  score_absenteeism  score_grad
# 0           3.1                1.4         3.2
# 1           3.6                2.4         NaN
# 2           3.8                0.0         NaN
# 3           3.6                0.0         NaN
# 4           0.1                1.1         NaN

# %%
avg_grades_district= school_overall_grades.groupby('district_name').mean().reset_index()

# %%
avg_grades_district.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   district_name      146 non-null    object
#  1   score_achievement  142 non-null    float64
#  2   score_growth       142 non-null    float64
#  3   score_absenteeism  142 non-null    float64
#  4   score_grad         123 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 5.8+ KB

# %%
rc_1 = by_district_teach_ret.merge(avg_grades_district, 
                        on = 'district_name')

# %%
rc_1.head()
# Out:
#                   district_name  percent_retained  score_achievement  \
# 0       Anderson County Schools              89.5           2.066667
# 1  Clinton City School District              82.6           2.600000
# 2        Oak Ridge City Schools              86.0           2.000000
# 3        Bedford County Schools              88.2           1.550000
# 4          Benton School System              94.3           2.080000
#
#    score_growth  score_absenteeism  score_grad
# 0      2.693333           1.346667    2.900000
# 1      3.133333           2.500000         NaN
# 2      1.900000           2.457143    3.000000
# 3      1.100000           2.464286    3.333333
# 4      3.000000           3.000000    4.000000

# %%
low_retention = rc_1[rc_1['percent_retained'] <85]
low_retention
# Out:
#                             district_name  percent_retained  \
# 1            Clinton City School District              82.6
# 17   West Carroll Special School District              79.3
# 21           Chester County School System              84.2
# 33         Metro Nashville Public Schools              82.2
# 39                 Fayette County Schools              81.3
# 42                  Humboldt City Schools              82.6
# 44        Trenton Special School District              83.1
# 47                   Giles County Schools              84.7
# 58                Rogersville City School              82.1
# 59                 Haywood County Schools              82.9
# 69                 Johnson County Schools              84.9
# 71              Lake County School System              80.9
# 81                     Etowah City School              64.5
# 84         Jackson-Madison County Schools              82.0
# 86          Richard Hardy Memorial School              78.3
# 88                   Maury County Schools              84.1
# 112                 Shelby County Schools              82.1
# 128                  Union County Schools              84.5
# 140           Achievement School District              54.3
#
#      score_achievement  score_growth  score_absenteeism  score_grad
# 1             2.600000      3.133333           2.500000         NaN
# 17            2.150000      3.100000           4.000000    4.000000
# 21            2.040000      0.950000           3.580000    3.400000
# 33            1.576712      1.826531           2.234694    2.573684
# 39            1.916667      2.457143           2.542857    4.000000
# 42            1.200000      1.950000           3.850000    2.400000
# 44            1.466667      1.933333           3.066667    4.000000
# 47            2.100000      1.542857           2.842857    3.700000
# 58            3.300000      2.800000           4.000000         NaN
# 59            0.650000      0.500000           1.100000    2.000000
# 69            2.000000      1.000000           2.666667    4.000000
# 71            1.933333      3.000000           1.733333    4.000000
# 81            1.800000      2.000000           4.000000         NaN
# 84            1.419048      1.823810           1.623810    2.600000
# 86            1.000000      1.000000           4.000000         NaN
# 88            1.360000      1.261905           2.386667    2.850000
# 112           1.735165      2.277596           3.539344    2.960000
# 128           1.575000      0.725000           3.462500    1.600000
# 140           1.376923      1.992593           2.492593    4.000000

# %%
low_retention.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19 entries, 1 to 140
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   district_name      19 non-null     object
#  1   percent_retained   19 non-null     float64
#  2   score_achievement  19 non-null     float64
#  3   score_growth       19 non-null     float64
#  4   score_absenteeism  19 non-null     float64
#  5   score_grad         15 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 1.0+ KB

# %%
ax = low_retention.plot(x='percent_retained', y='score_achievement', kind='scatter', c='tab:blue', label='score_achievement')
plt.show()

# %%
low_retention.corr().style.background_gradient(cmap="Blues")
# Out:
# <style  type="text/css" >
# #T_b3b4f_row0_col0,#T_b3b4f_row1_col1,#T_b3b4f_row2_col2,#T_b3b4f_row3_col3,#T_b3b4f_row4_col4{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_b3b4f_row0_col1,#T_b3b4f_row0_col2,#T_b3b4f_row0_col3,#T_b3b4f_row0_col4,#T_b3b4f_row4_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_b3b4f_row1_col0{
#             background-color:  #aacfe5;
#             color:  #000000;
#         }#T_b3b4f_row1_col2,#T_b3b4f_row2_col4{
#             background-color:  #3888c1;
#             color:  #000000;
#         }#T_b3b4f_row1_col3{
#             background-color:  #99c7e0;
#             color:  #000000;
#         }#T_b3b4f_row1_col4{
#             background-color:  #2a7ab9;
#             color:  #000000;
#         }#T_b3b4f_row2_col0{
#             background-color:  #e0ecf8;
#             color:  #000000;
#         }#T_b3b4f_row2_col1{
#             background-color:  #5ba3d0;
#             color:  #000000;
#         }#T_b3b4f_row2_col3{
#             background-color:  #cfe1f2;
#             color:  #000000;
#         }#T_b3b4f_row3_col0{
#             background-color:  #d8e7f5;
#             color:  #000000;
#         }#T_b3b4f_row3_col1{
#             background-color:  #ccdff1;
#             color:  #000000;
#         }#T_b3b4f_row3_col2{
#             background-color:  #c7dbef;
#             color:  #000000;
#         }#T_b3b4f_row3_col4{
#             background-color:  #afd1e7;
#             color:  #000000;
#         }#T_b3b4f_row4_col1{
#             background-color:  #539ecd;
#             color:  #000000;
#         }#T_b3b4f_row4_col2{
#             background-color:  #4493c7;
#             color:  #000000;
#         }#T_b3b4f_row4_col3{
#             background-color:  #d1e2f3;
#             color:  #000000;
#         }</style><table id="T_b3b4f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >percent_retained</th>        <th class="col_heading level0 col1" >score_achievement</th>        <th class="col_heading level0 col2" >score_growth</th>        <th class="col_heading level0 col3" >score_absenteeism</th>        <th class="col_heading level0 col4" >score_grad</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b3b4f_level0_row0" class="row_heading level0 row0" >percent_retained</th>
#                         <td id="T_b3b4f_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_b3b4f_row0_col1" class="data row0 col1" >0.132880</td>
#                         <td id="T_b3b4f_row0_col2" class="data row0 col2" >-0.158612</td>
#                         <td id="T_b3b4f_row0_col3" class="data row0 col3" >-0.101505</td>
#                         <td id="T_b3b4f_row0_col4" class="data row0 col4" >-0.309605</td>
#             </tr>
#             <tr>
#                         <th id="T_b3b4f_level0_row1" class="row_heading level0 row1" >score_achievement</th>
#                         <td id="T_b3b4f_row1_col0" class="data row1 col0" >0.132880</td>
#                         <td id="T_b3b4f_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_b3b4f_row1_col2" class="data row1 col2" >0.608463</td>
#                         <td id="T_b3b4f_row1_col3" class="data row1 col3" >0.324531</td>
#                         <td id="T_b3b4f_row1_col4" class="data row1 col4" >0.630546</td>
#             </tr>
#             <tr>
#                         <th id="T_b3b4f_level0_row2" class="row_heading level0 row2" >score_growth</th>
#                         <td id="T_b3b4f_row2_col0" class="data row2 col0" >-0.158612</td>
#                         <td id="T_b3b4f_row2_col1" class="data row2 col1" >0.608463</td>
#                         <td id="T_b3b4f_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_b3b4f_row2_col3" class="data row2 col3" >0.126534</td>
#                         <td id="T_b3b4f_row2_col4" class="data row2 col4" >0.559772</td>
#             </tr>
#             <tr>
#                         <th id="T_b3b4f_level0_row3" class="row_heading level0 row3" >score_absenteeism</th>
#                         <td id="T_b3b4f_row3_col0" class="data row3 col0" >-0.101505</td>
#                         <td id="T_b3b4f_row3_col1" class="data row3 col1" >0.324531</td>
#                         <td id="T_b3b4f_row3_col2" class="data row3 col2" >0.126534</td>
#                         <td id="T_b3b4f_row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_b3b4f_row3_col4" class="data row3 col4" >0.111477</td>
#             </tr>
#             <tr>
#                         <th id="T_b3b4f_level0_row4" class="row_heading level0 row4" >score_grad</th>
#                         <td id="T_b3b4f_row4_col0" class="data row4 col0" >-0.309605</td>
#                         <td id="T_b3b4f_row4_col1" class="data row4 col1" >0.630546</td>
#                         <td id="T_b3b4f_row4_col2" class="data row4 col2" >0.559772</td>
#                         <td id="T_b3b4f_row4_col3" class="data row4 col3" >0.111477</td>
#                         <td id="T_b3b4f_row4_col4" class="data row4 col4" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
low_retention.plot(
    x='percent_retained', 
    y= 'score_achievement', 
    kind='scatter', 
    c='cornflowerblue',
    title='Schools with Low Teacher Retention',
    xlabel='Student Achievement',
    ylabel='Teacher Retention',
    #s='Size'
)

plt.show()

# %%
rc_1.corr().style.background_gradient(cmap="Blues")
# Out:
# <style  type="text/css" >
# #T_c409b_row0_col0,#T_c409b_row1_col1,#T_c409b_row2_col2,#T_c409b_row3_col3,#T_c409b_row4_col4{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_c409b_row0_col1,#T_c409b_row0_col3,#T_c409b_row0_col4,#T_c409b_row3_col0,#T_c409b_row3_col2{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_c409b_row0_col2{
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }#T_c409b_row1_col0,#T_c409b_row3_col4{
#             background-color:  #e0ecf8;
#             color:  #000000;
#         }#T_c409b_row1_col2{
#             background-color:  #a0cbe2;
#             color:  #000000;
#         }#T_c409b_row1_col3{
#             background-color:  #bcd7eb;
#             color:  #000000;
#         }#T_c409b_row1_col4,#T_c409b_row4_col3{
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }#T_c409b_row2_col0{
#             background-color:  #ccdff1;
#             color:  #000000;
#         }#T_c409b_row2_col1{
#             background-color:  #94c4df;
#             color:  #000000;
#         }#T_c409b_row2_col3{
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }#T_c409b_row2_col4{
#             background-color:  #d6e6f4;
#             color:  #000000;
#         }#T_c409b_row3_col1{
#             background-color:  #d3e3f3;
#             color:  #000000;
#         }#T_c409b_row4_col0{
#             background-color:  #eff6fc;
#             color:  #000000;
#         }#T_c409b_row4_col1{
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }#T_c409b_row4_col2{
#             background-color:  #edf4fc;
#             color:  #000000;
#         }</style><table id="T_c409b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >percent_retained</th>        <th class="col_heading level0 col1" >score_achievement</th>        <th class="col_heading level0 col2" >score_growth</th>        <th class="col_heading level0 col3" >score_absenteeism</th>        <th class="col_heading level0 col4" >score_grad</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c409b_level0_row0" class="row_heading level0 row0" >percent_retained</th>
#                         <td id="T_c409b_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_c409b_row0_col1" class="data row0 col1" >0.101212</td>
#                         <td id="T_c409b_row0_col2" class="data row0 col2" >0.206338</td>
#                         <td id="T_c409b_row0_col3" class="data row0 col3" >-0.016930</td>
#                         <td id="T_c409b_row0_col4" class="data row0 col4" >0.026178</td>
#             </tr>
#             <tr>
#                         <th id="T_c409b_level0_row1" class="row_heading level0 row1" >score_achievement</th>
#                         <td id="T_c409b_row1_col0" class="data row1 col0" >0.101212</td>
#                         <td id="T_c409b_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_c409b_row1_col2" class="data row1 col2" >0.460054</td>
#                         <td id="T_c409b_row1_col3" class="data row1 col3" >0.269532</td>
#                         <td id="T_c409b_row1_col4" class="data row1 col4" >0.172328</td>
#             </tr>
#             <tr>
#                         <th id="T_c409b_level0_row2" class="row_heading level0 row2" >score_growth</th>
#                         <td id="T_c409b_row2_col0" class="data row2 col0" >0.206338</td>
#                         <td id="T_c409b_row2_col1" class="data row2 col1" >0.460054</td>
#                         <td id="T_c409b_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_c409b_row2_col3" class="data row2 col3" >0.141903</td>
#                         <td id="T_c409b_row2_col4" class="data row2 col4" >0.186923</td>
#             </tr>
#             <tr>
#                         <th id="T_c409b_level0_row3" class="row_heading level0 row3" >score_absenteeism</th>
#                         <td id="T_c409b_row3_col0" class="data row3 col0" >-0.016930</td>
#                         <td id="T_c409b_row3_col1" class="data row3 col1" >0.269532</td>
#                         <td id="T_c409b_row3_col2" class="data row3 col2" >0.141903</td>
#                         <td id="T_c409b_row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_c409b_row3_col4" class="data row3 col4" >0.137950</td>
#             </tr>
#             <tr>
#                         <th id="T_c409b_level0_row4" class="row_heading level0 row4" >score_grad</th>
#                         <td id="T_c409b_row4_col0" class="data row4 col0" >0.026178</td>
#                         <td id="T_c409b_row4_col1" class="data row4 col1" >0.172328</td>
#                         <td id="T_c409b_row4_col2" class="data row4 col2" >0.186923</td>
#                         <td id="T_c409b_row4_col3" class="data row4 col3" >0.137950</td>
#                         <td id="T_c409b_row4_col4" class="data row4 col4" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
ax = rc_1.plot(x='percent_retained', y='score_achievement', kind='scatter', c='lightsteelblue', edgecolor='black', s=30, label='score_achievement')
rc_1.plot(x='percent_retained', y='score_growth', kind='scatter', ax=ax, c='tab:brown', edgecolor='black', s=30, label='score_growth')

plt.show()



#plot.scatter(x = , y = )
